# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
import random


# %matplotlib inline

data = load_boston()
# print(data)
X, y = data['data'], data['target']
print(X)


def draw_rm_and_price():
    plt.scatter(X[:, 5], y)
    
# draw_rm_and_price()
def price(rm, k, b):
    return rm * k + b

X_rm = X[:, 5]
k = random.randint(-100, 100)
b = random.randint(-100, 100)

price_random_k_and_b = [price(r, k, b) for r in X_rm]

try_time = 2000
min_loss = float('inf')
                     
k = random.random() * 200 - 100
b = random.random() * 200 - 100

# draw_rm_and_price()
# plt.scatter(X_rm, price_randon_k_and_b)


def loss(y, y_hat):
    return sum((y_i - y_hat_i)**2 for y_i, y_hat_i in zip(list(y), list(y_hat))) / len(list(y))


def partial_k(x, y, y_hat):
    n = len(y)
    return -2 / n * (sum((y_i - y_hat_i) * x_i for x_i, y_i, y_hat_i in zip(list(x), list(y), list(y_hat))))

                    
def partial_b(y, y_hat):
    n = len(y)
    return -2 / n * (sum((y_i - y_hat_i) for y_i, y_hat_i in zip(list(y), list(y_hat))))
                     
                     
# direction = [
#     (+1, -1),
#     (+1, +1),
#     (-1, -1),
#     (-1, +1),
# ]                     
                     
# next_direction = random.choice(direction)

scalar = 0.1

update_time = 0
                     
learning_rate = 0.00001
                     
#                      wheh gradient is small, then the learning rate should be big and vice versa

for i in range(try_time):

#     price_random_k_and_b = [price(r, k, b) for r in X_rm]
    
#     current_loss = loss(y, price_randon_k_and_b)
    
#     if current_loss < min_loss:
#         min_loss = current_loss
#         best_k, best_b = k, b
#         print("{}---- k : {}, b: {}, and loss : {}".format(i, best_k, best_b, min_loss))
                                         
                     
#     k_direction, b_direction = next_direction
#     current_k, current_b = best_k + k_direction * scalar, best_b + b_direction * scalar
                     
    price_by_k_and_b = [price(r, current_k, current_b) for r in X_rm]
                     
    current_loss = loss(y, price_by_k_and_b)
                     
    if current_loss < min_loss:
        min_loss = current_loss
        if i % 50 ==0:
            print("{}---- k : {}, b: {}, and loss : {}".format(i, best_k, best_b, min_loss))
                     
    k_gradient = partial_k(x, y, price_by_k_and_b)
    b_gradient = partial_b(y, price_by_k_and_b)
                     
    current_k = (current_k - k_gradient) * learning_rate
    current_b = (current_b - b_gradient) * learning_rate
                     
                    
                     
                     
# #         best_k, best_b = current_k, current_b

#         next_direction = next_direction
#         update_time += 1
                     
#         if update_time % 10 == 0
            
                     
#     k_direction = partial_k(x, y, price_by_k_and_b)
#     b_direction = partial_b(y, price_by_k_and_b) 
#         else:
#             next_direction = random.choice(direction)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2c09701d1534> in <module>()
#      81 #     current_k, current_b = best_k + k_direction * scalar, best_b + b_direction * scalar
#      82
# ---> 83     price_by_k_and_b = [price(r, current_k, current_b) for r in X_rm]
#      84
#      85     current_loss = loss(y, price_by_k_and_b)
#
# <ipython-input-7-2c09701d1534> in <listcomp>(.0)
# ...

# %% [markdown]
# $$ loss = \frac(1){n} \ sum(y_i - (kx_i + b_i))^2 $$

# %% [raw]
# Dynamic Programming

# %%
from collections import defaultdict

original_price = [1, 5, 8, 9, 10, 17, 17, 20, 24, 30]
price = defaultdict(int)
# some_default_dict[1] = 0

def get_call_time(f):
    result = f()
    print("function: {}called once!" .format(f.__name__))
    called_time[f.__name__] += 1
    
    return result

for i, p in enumerate(original_price):
    price[i + 1] = p
    
def revenue(n):
    return max(
        [ price[n]] + [revenue(1) + revenue(n-i) for i in range(1, n)]
#          price[n], max(revenue(i) + revenue(n - i) for i in range(1, n))
    )

revenue(10)
# Out:
# 30

# %%
from collections import defaultdict

def example(f, arg):
    return f(arg)

def add_ten(num):
    return num + 10

def mul_ten(num):
    return num*10

operations = [add_ten, mul_ten]

# for f in operations:
#     print(example(f, 100))

called_time = defaultdict(int)
called_time_with_arg = defaultdict(int)

def get_called_time(f):
    result = f()
    print('function:{} called once'.format(f.__name__))
    called_time[f.__name__] += 1
    
    return result

def r(n):
    fname = r.__name__
    
    called_time_with_arg[(fname, n)] += 1
    return max(
            [ price[n]] + [revenue(1) + revenue(n-i) for i in range(1, n)]
    )
    
r(15)
called_time_with_arg
# Out:
# defaultdict(int, {('r', 15): 1})

# %%
from collections import defaultdict
from functools import wraps


original_price = [1, 5, 8, 9, 10, 17, 17, 20, 24, 30, 35]

price = defaultdict(int)

for i, p in enumerate(original_price):
    price[i + 1] = p
# price[11]

# max(1, 2, 3, 4)

def example(f, arg):
    return f(arg)

def add_ten(num):
    return num + 10

def mul_ten(num):
    return num * 10

operations = [add_ten, mul_ten]

# for f in operations:
#     print(example(f, 100))

called_time = defaultdict(int)

def get_call_times(f):
    result = f()
    print('function: {} called once!'. format(f.__name__))
    called_time[f.__name__] += 1
    
    return result

def some_function_1(): print("I am function 1")
    
# get_call_times(some_function_1)
# called_time

call_time_with_arg = defaultdict(int)

def r(n):
    return max(
    [price[n]] + [r(i) + r(n - i) for i in range(1, n)]
    )

def get_call_time(f):
    @wraps(f)
    def wrap(n):
        print("I can count")
        result = f(n)
        call_time_with_arg[(f.__name__, n)] += 1
        return result
    return wrap

# add_ten(10)
add_ten = get_call_time(add_ten)

@get_call_time
def add_20(n): return n+20

# add_20 = get_call_time(add_20)
# add_20(9)

called_time_with_arg = defaultdict(int)
solution = {}
# memo.already_computed = {}

# @memo
def r(n):
    max_price, max_split = max(
    [(price[n], 0)] + [(r(i) + r(n-i), i) for i in range(1, n)], key = lambda x: x[0]
    )
    
    solution[n] = (n - max_split, max_split)
    return max_price

# r(15)
# solution

def parse_solution(n):
    left_split, right_split = solution[n]
    
    if right_split == 0: return[left_split]
    return parse_solution(left_split) + parse_solution(right_split)

# r(23)
# parse_solution(23)

def memo(f):
    memo.already_computed= {}
    @wraps(f)
    def _wrap(arg):
        result = None
        
        if arg in memo.already_computed:
            result = memo.already_computed[arg]
        else:
            result = f(arg)
            memo.already_computed[arg] = result
            
        return result
    return _wrap

r(20)
